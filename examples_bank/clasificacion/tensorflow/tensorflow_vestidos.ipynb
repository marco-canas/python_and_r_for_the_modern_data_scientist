# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/introducci-n-al-Machine-Learning/blob/main/classes/class_1/class_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# # Clasificación usando redes neuronales

# %% [markdown]
# ## [Video de apoyo](https://www.youtube.com/watch?v=frBLTtFAWyI&lc=UgwrCJGAHkJRKQtxGwl4AaABAg)

# %%
from tensorflow import keras
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22024/1589520110.py in <module>
# ----> 1 from tensorflow import keras
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
from keras.datasets import fashion_mnist
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22024/1812007660.py in <module>
# ----> 1 from keras.datasets import fashion_mnist
#
# ModuleNotFoundError: No module named 'keras'

# %%
fashion_mnist = keras.datasets.fashion_mnist

# %%
conda install -c conda-forge tensorflow
# Out:
# ...
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
#
# Note: you may need to restart the kernel to use updated packages.
# ...
# Examining urllib3:  94%|#########4| 352/374 [20:38<01:41,  4.61s/it]
# ...
#
# Package twisted conflicts for:
# jupyter_server -> prometheus_client -> twisted
# prometheus_client -> twisted
# notebook -> prometheus_client -> twisted
#
# Package isort conflicts for:
# python-lsp-server -> pylint[version='>=2.5.0'] -> isort[version='>=4.2.5,<5|>=4.2.5,<6']
# anaconda==2021.11 -> pylint==2.9.6=py39haa95532_1 -> isort[version='>=4.2.5,<6']
# ...
